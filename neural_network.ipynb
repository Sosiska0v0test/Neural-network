# %% [markdown]
# <a href="https://colab.research.google.com/github/Sosiska0v0test/Neural-network/blob/main/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
# %matplotlib inline
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import utils

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
plt.imshow(x_train[949])
plt.colorbar()
plt.grid(False)

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
plt.figure()
plt.imshow(x_train[555])
plt.colorbar()
plt.grid(False)

# %%
plt.figure(figsize=(10, 10))
for i in range (25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(x_train[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[y_train[1]])

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(128, activation="relu"),
                          keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dense_3 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Teaching the model to recognize photos of clothes

# %%
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.7433 - accuracy: 0.7594
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5150 - accuracy: 0.8258
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4683 - accuracy: 0.8401
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4431 - accuracy: 0.8469
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4258 - accuracy: 0.8532
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4106 - accuracy: 0.8588
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3990 - accuracy: 0.8624
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3883 - accuracy: 0.8655
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3794 - accuracy: 0.8691
# Epoch 10/10
# ...

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy-->', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4081 - accuracy: 0.8544
# Test accuracy--> 0.8543999791145325

# %%
# prediction

# %%
predictions = model.predict(x_train)
# Out:
# 1875/1875 [==============================] - 4s 2ms/step

# %%
predictions[0]
# Out:
# array([2.9205905e-08, 2.7584048e-09, 4.0581636e-09, 1.1289060e-08,
#        1.1388502e-08, 2.4071416e-04, 1.7208355e-07, 7.9362717e-04,
#        6.9247144e-06, 9.9895835e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
y_train[0]
# Out:
# 9

# %%
plt.figure()
plt.imshow(x_train[13])
plt.colorbar()
plt.grid(False)

# %%
class_names[np.argmax(predictions[13])]
# Out:
# 'Sandal'
